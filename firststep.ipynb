# %% [markdown]
# # Importation des librairies

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# # 1. Prétraitement et visualisation des données

# %%
#Chargement du dataset
house = pd.read_csv("data/kc_house_data.csv", encoding="iso-8859-1")

# %%
#Copie du dataset
df=house.copy()

# %%
#Affichage de l'entête
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#Changement de l'index
df.set_index('id')
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
#affichage des infos sur l'ensemble du dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [raw]
# On remarque qu'il n'y a pas de valeurs manquantes et toutes nos données sont de types numériques à part les dates

# %%
#Affichage des statistiques descriptives
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df['floors'].value_counts().to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
#Utilisons la fonction boxplot avec seaborn pour voir les valeurs aberrantes sur le prix selon la vue sur mer
sns.boxplot(x="waterfront", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
#Utilisons la fonction boxplot avec seaborn pour voir les valeurs aberrantes sur le prix selon le nombre d'étages
sns.boxplot(x="floors", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
#Utilisons corr() pour trouver la caractéristique autre que le prix qui est la plus corrélée avec le prix
df.corr()['price'].sort_values().to_frame()
# Out:
#                   price
# zipcode       -0.053203
# id            -0.016762
# long           0.021626
# condition      0.036362
# yr_built       0.054012
# sqft_lot15     0.082447
# sqft_lot       0.089661
# yr_renovated   0.126434
# floors         0.256794
# waterfront     0.266369
# lat            0.307003
# bedrooms       0.308350
# sqft_basement  0.323816
# view           0.397293
# bathrooms      0.525138
# sqft_living15  0.585379
# sqft_above     0.605567
# grade          0.667434
# sqft_living    0.702035
# price          1.000000

# %% [raw]
# On remarque que sqft_living (surface de la maison) est plus corrélée avec le prix

# %% [markdown]
# # 2. Sélection des caractéristiques les plus importantes

# %% [raw]
# Avec la sortie de la méthode corr() nous sélectionnons sqft_living(surface de la maison), grade(note), sqft_above(surface en dehors du sous-sol), bathrooms(nombre de salle de bains) et bedrooms(nombre de chambres)

# %% [markdown]
# # 3. Division de notre ensemble de données en un ensemble d'apprentissage et un ensemble de test

# %%
y_data = df['price'] #target

x_data=df.drop('price',axis=1) #features

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.20, random_state=1)


print("Number of test samples :", x_test.shape[0])
print("Number of training samples:",x_train.shape[0])
# Out:
# Number of test samples : 4323
# Number of training samples: 17290

# %% [raw]
# Nous avons divisé notre dataset avec 80% pour l'entrainnement et 20% pour le test

# %% [markdown]
# # 4. Application de la régression linéaire à votre ensemble d'entraînement.

# %%
lre=LinearRegression()

lre.fit(x_train[['sqft_living']], y_train) #training
lre.score(x_test[['sqft_living']], y_test) #score sur le test
# Out:
# 0.5033019006466928

# %% [markdown]
# # 5.Tracé de la régression linéaire.

# %%
plt.scatter(x_data[['sqft_living']],y_data,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x_data[['sqft_living']],lre.predict(x_data[['sqft_living']]),color="k")
plt.show()

# %% [raw]
# On remarque la sensiblité des valeurs aberrantes

# %% [markdown]
# # 5. Mesure des performances de la régression linéaire à l'aide de l'ensemble de test

# %%
x=df["sqft_living"].values.reshape(-1, 1)
y=df["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417

# %% [raw]
# On remarque que la moitié de la variation de sortie peut être expliquée par les modèles d'entrée

# %% [markdown]
# # 6. Application  d'une régression multilinéaire

# %%
x=df[["sqft_living", "grade", "sqft_above", "bathrooms", "sqft_living15","bedrooms"]]
y=df["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print(model.score(x_test[["sqft_living", "grade", "sqft_above", "bathrooms", "sqft_living15","bedrooms"]], y_test))
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# 0.5521927394220376
# MSE 56297223002.62542
# R squared 0.5521927394220376

# %% [raw]
# La regression multilinéaire est plus performante que la regression linéaire.

# %% [markdown]
# # 7.  Application de la régression polynomiale

# %%
x= df[["sqft_living", "grade", "sqft_above", "bathrooms", "sqft_living15","bedrooms"]]
y= df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  51915372482.14795
# R squared:  0.5870474688950282

# %% [raw]
# La regression polynomiale est plus performante que la regression linéaire et multilinéaire.

# %%
#Trçons la regression polynomiale
x= df["sqft_living"].values.reshape(-1,1)
y= df["price"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Polynomial regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
